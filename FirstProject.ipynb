# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidah27/Shahidah27/blob/main/FirstProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
strNum = input("Enter a number >>")
intNum = int(strNum)
squareNum = intNum ** 2
print(squareNum)
# Out:
# Hello World!
# Enter a number >>2
# 4

# %%
myList = []
myList.append(1)
myList.append(7)
myList.append(3)

print(myList[0]) #prints 1
print(myList[1]) #prints 2
print(myList[2]) #prints 3

for x in myList:
  print(x)
# Out:
# 1
# 7
# 3
# 1
# 7
# 3

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif b < a:
  print("a is greater than b")
else:
  print("a and b is equal")
# Out:
# a is greater than b
